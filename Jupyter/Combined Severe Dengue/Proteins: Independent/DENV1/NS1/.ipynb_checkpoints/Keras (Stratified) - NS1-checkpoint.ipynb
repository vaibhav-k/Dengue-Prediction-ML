# %%
# Importing the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Importing the protein data
k2 = []
k2d = []

f = open("../../../../../../Data/Proteins/DENV1/NS1/DENV1_NS1.txt", "r")
for x in f:
    if "DSS" in x:
        k2d.append(1)
    elif "DHF" in x:
        k2d.append(1)
    elif x[0] == ">":
        k2d.append(0)
    else:
        x = x.replace("\n", "")
        k2.append(x)
        
# Converting the array into DataFrame
k2 = pd.DataFrame(k2)

# Attaching the "Disease" label column to the input
k2["Disease"] = k2d

# Renaming the columns
k2 = k2.rename(index=str, columns={0: "Sequence", "Disease": "Disease"})

# clearing the memory
del k2d

# %%
print("The combined shape of the given data is:", str(k2.shape))
print("The length of the combined data is:", str(len(k2.index)))
print("Does the combined data have any null value? ->", k2.isnull().values.any())

k2 = k2.dropna(how = 'any', axis = 0) 

# Shuffling the data and then taking a peek
k2 = k2.sample(frac = 1)
# Out:
# The combined shape of the given data is: (999, 2)
# The length of the combined data is: 999
# Does the combined data have any null value? -> False

# %%
# Function to convert sequence strings into k-mer words, default size = 6 (hexamer words)
def getKmers(sequence, size = 6):
    return [sequence[x:x + size].lower() for x in range(len(sequence) - size + 1)]

k2['words'] = k2.apply(lambda x: getKmers(x['Sequence']), axis = 1)
k2 = k2.drop('Sequence', axis=1)

k2_texts = list(k2['words'])
for item in range(len(k2_texts)):
    k2_texts[item] = ' '.join(k2_texts[item])

# %%
# Creating y and printing the shape of it
y = k2.iloc[:, 0].values

# Checking the balance of the disease severity
k2["Disease"].value_counts().sort_index().plot.bar()

# clearing the memory
del k2

# %%
# Creating the Bag of Words model using CountVectorizer()
# This is equivalent to k-mer counting
# The n-gram size of 4 was previously determined by testing
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(ngram_range=(4,4))
x = cv.fit_transform(k2_texts)

# clearing the memory
del cv

# %%
# Splitting the human dataset into the training set and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 42, stratify=y)

# Printing the shapes of the train and test matrices
print("The shape of x_train is:", X_train.shape)
print("The shape of y_train is:", y_train.shape)
print("The shape of x_test is:", X_test.shape)
print("The shape of y_test is:", y_test.shape)

# clearing the memory
del x
del y
# Out:
# The shape of x_train is: (799, 1761)
# The shape of y_train is: (799,)
# The shape of x_test is: (200, 1761)
# The shape of y_test is: (200,)

# %% [markdown]
# ## Keras

# %%
# Importing the Keras libraries
from keras.models import Sequential
from keras.layers import Dense

# define the keras model
model = Sequential()
model.add(Dense(12, input_dim=1761, activation='relu'))
model.add(Dense(15, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0323 11:08:14.497812 140393505400640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0323 11:08:14.517331 140393505400640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0323 11:08:14.519550 140393505400640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# fit the keras model on the dataset
model.fit(X_train, y_train, epochs=150, batch_size=10)
# Out:
# W0323 11:08:14.579628 140393505400640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0323 11:08:14.615698 140393505400640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0323 11:08:14.621242 140393505400640 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0323 11:08:14.858065 140393505400640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/150
# 799/799 [==============================] - 1s 649us/step - loss: 0.6363 - acc: 0.5857
# Epoch 2/150
# 799/799 [==============================] - 0s 153us/step - loss: 0.6316 - acc: 0.5707
# Epoch 3/150
# 799/799 [==============================] - 0s 155us/step - loss: 0.6131 - acc: 0.6020
# Epoch 4/150
# 799/799 [==============================] - 0s 154us/step - loss: 0.6148 - acc: 0.5782
# Epoch 5/150
# 799/799 [==============================] - 0s 155us/step - loss: 0.6086 - acc: 0.6083
# Epoch 6/150
# 799/799 [==============================] - 0s 152us/step - loss: 0.6038 - acc: 0.5957
# Epoch 7/150
# 799/799 [==============================] - 0s 154us/step - loss: 0.6050 - acc: 0.5982
# Epoch 8/150
# 799/799 [==============================] - 0s 164us/step - loss: 0.6020 - acc: 0.6045
# Epoch 9/150
# 799/799 [==============================] - 0s 161us/step - loss: 0.5916 - acc: 0.6195
# Epoch 10/150
# 799/799 [==============================] - 0s 162us/step - loss: 0.6032 - acc: 0.5882
# Epoch 11/150
# 799/799 [==============================] - 0s 163us/step - loss: 0.5902 - acc: 0.6283
# Epoch 12/150
# 799/799 [==============================] - 0s 152us/step - loss: 0.5872 - acc: 0.6283
# Epoch 13/150
# 799/799 [==============================] - 0s 159us/step - loss: 0.5828 - acc: 0.6183
# Epoch 14/150
# 799/799 [==============================] - 0s 162us/step - loss: 0.5794 - acc: 0.6408
# Epoch 15/150
# 799/799 [==============================] - 0s 176us/step - loss: 0.5750 - acc: 0.6408
# Epoch 16/150
# 799/799 [==============================] - 0s 164us/step - loss: 0.5717 - acc: 0.6546
# Epoch 17/150
# 799/799 [==============================] - 0s 169us/step - loss: 0.5812 - acc: 0.6358
# Epoch 18/150
# 799/799 [==============================] - 0s 162us/step - loss: 0.5690 - acc: 0.6571
# Epoch 19/150
# 799/799 [==============================] - 0s 164us/step - loss: 0.5902 - acc: 0.6145
# Epoch 20/150
# 799/799 [==============================] - 0s 153us/step - loss: 0.5772 - acc: 0.6308
# Epoch 21/150
# 799/799 [==============================] - 0s 150us/step - loss: 0.5667 - acc: 0.6483
# Epoch 22/150
# 799/799 [==============================] - 0s 153us/step - loss: 0.5776 - acc: 0.6258
# Epoch 23/150
# 799/799 [==============================] - 0s 170us/step - loss: 0.5829 - acc: 0.6170
# Epoch 24/150
# 799/799 [==============================] - 0s 189us/step - loss: 0.5606 - acc: 0.6421
# Epoch 25/150
# 799/799 [==============================] - 0s 238us/step - loss: 0.5594 - acc: 0.6433
# Epoch 26/150
# 799/799 [==============================] - 0s 208us/step - loss: 0.5585 - acc: 0.6533
# Epoch 27/150
# 799/799 [==============================] - 0s 176us/step - loss: 0.5584 - acc: 0.6608
# Epoch 28/150
# 799/799 [==============================] - 0s 246us/step - loss: 0.5624 - acc: 0.6295
# Epoch 29/150
# 799/799 [==============================] - 0s 215us/step - loss: 0.5534 - acc: 0.6608
# Epoch 30/150
# 799/799 [==============================] - 0s 152us/step - loss: 0.5540 - acc: 0.6383
# Epoch 31/150
# 799/799 [==============================] - 0s 205us/step - loss: 0.5484 - acc: 0.6496
# Epoch 32/150
# 799/799 [==============================] - 0s 181us/step - loss: 0.5475 - acc: 0.6345
# Epoch 33/150
# 799/799 [==============================] - 0s 195us/step - loss: 0.5468 - acc: 0.6721
# Epoch 34/150
# 799/799 [==============================] - 0s 176us/step - loss: 0.5511 - acc: 0.6471
# Epoch 35/150
# 799/799 [==============================] - 0s 307us/step - loss: 0.5425 - acc: 0.6483
# Epoch 36/150
# 799/799 [==============================] - 0s 158us/step - loss: 0.5476 - acc: 0.6708
# Epoch 37/150
# 799/799 [==============================] - 0s 163us/step - loss: 0.5473 - acc: 0.6621
# Epoch 38/150
# 799/799 [==============================] - 0s 161us/step - loss: 0.5415 - acc: 0.6483
# Epoch 39/150
# 799/799 [==============================] - 0s 162us/step - loss: 0.5472 - acc: 0.6583
# Epoch 40/150
# 799/799 [==============================] - 0s 159us/step - loss: 0.5408 - acc: 0.6433
# Epoch 41/150
# 799/799 [==============================] - 0s 160us/step - loss: 0.5463 - acc: 0.6433
# Epoch 42/150
# 799/799 [==============================] - 0s 201us/step - loss: 0.5523 - acc: 0.6358
# Epoch 43/150
# 799/799 [==============================] - 0s 162us/step - loss: 0.5463 - acc: 0.6358
# Epoch 44/150
# 799/799 [==============================] - 0s 162us/step - loss: 0.5403 - acc: 0.6558
# Epoch 45/150
# 799/799 [==============================] - 0s 153us/step - loss: 0.5399 - acc: 0.6621
# Epoch 46/150
# 799/799 [==============================] - 0s 150us/step - loss: 0.5478 - acc: 0.6608
# Epoch 47/150
# 799/799 [==============================] - 0s 190us/step - loss: 0.5379 - acc: 0.6446
# Epoch 48/150
# 799/799 [==============================] - 0s 286us/step - loss: 0.5395 - acc: 0.6458
# Epoch 49/150
# 799/799 [==============================] - 0s 175us/step - loss: 0.5494 - acc: 0.6283
# Epoch 50/150
# 799/799 [==============================] - 0s 166us/step - loss: 0.5365 - acc: 0.6421
# Epoch 51/150
# 799/799 [==============================] - 0s 163us/step - loss: 0.5378 - acc: 0.6671
# Epoch 52/150
# 799/799 [==============================] - 0s 162us/step - loss: 0.5367 - acc: 0.6558
# Epoch 53/150
# 799/799 [==============================] - 0s 168us/step - loss: 0.5333 - acc: 0.6708
# Epoch 54/150
# 799/799 [==============================] - 0s 177us/step - loss: 0.5380 - acc: 0.6308
# Epoch 55/150
# 799/799 [==============================] - 0s 164us/step - loss: 0.5335 - acc: 0.6558
# Epoch 56/150
# 799/799 [==============================] - 0s 210us/step - loss: 0.5338 - acc: 0.6408
# Epoch 57/150
# 799/799 [==============================] - 0s 195us/step - loss: 0.5368 - acc: 0.6646
# Epoch 58/150
# 799/799 [==============================] - 0s 175us/step - loss: 0.5434 - acc: 0.6508
# Epoch 59/150
# 799/799 [==============================] - 0s 172us/step - loss: 0.5385 - acc: 0.6533
# Epoch 60/150
# 799/799 [==============================] - 0s 159us/step - loss: 0.5425 - acc: 0.6383
# Epoch 61/150
# 799/799 [==============================] - 0s 165us/step - loss: 0.5346 - acc: 0.6533
# Epoch 62/150
# 799/799 [==============================] - 0s 180us/step - loss: 0.5334 - acc: 0.6708
# Epoch 63/150
# 799/799 [==============================] - 0s 215us/step - loss: 0.5328 - acc: 0.6446
# Epoch 64/150
# 799/799 [==============================] - 0s 257us/step - loss: 0.5316 - acc: 0.6370
# Epoch 65/150
# 799/799 [==============================] - 0s 221us/step - loss: 0.5366 - acc: 0.6533
# Epoch 66/150
# 799/799 [==============================] - 0s 237us/step - loss: 0.5318 - acc: 0.6658
# Epoch 67/150
# 799/799 [==============================] - 0s 317us/step - loss: 0.5370 - acc: 0.6571
# Epoch 68/150
# 799/799 [==============================] - 0s 277us/step - loss: 0.5307 - acc: 0.6608
# Epoch 69/150
# 799/799 [==============================] - 0s 214us/step - loss: 0.5313 - acc: 0.6483
# Epoch 70/150
# 799/799 [==============================] - 0s 196us/step - loss: 0.5432 - acc: 0.6508
# Epoch 71/150
# 799/799 [==============================] - 0s 182us/step - loss: 0.5366 - acc: 0.6508
# Epoch 72/150
# 799/799 [==============================] - 0s 183us/step - loss: 0.5315 - acc: 0.6508
# Epoch 73/150
# 799/799 [==============================] - 0s 175us/step - loss: 0.5394 - acc: 0.6733
# Epoch 74/150
# 799/799 [==============================] - 0s 177us/step - loss: 0.5282 - acc: 0.6471
# Epoch 75/150
# 799/799 [==============================] - 0s 177us/step - loss: 0.5314 - acc: 0.6646
# Epoch 76/150
# 799/799 [==============================] - 0s 225us/step - loss: 0.5279 - acc: 0.6809
# Epoch 77/150
# 799/799 [==============================] - 0s 172us/step - loss: 0.5294 - acc: 0.6683
# Epoch 78/150
# 799/799 [==============================] - 0s 227us/step - loss: 0.5288 - acc: 0.6683
# Epoch 79/150
# 799/799 [==============================] - 0s 293us/step - loss: 0.5302 - acc: 0.6508
# Epoch 80/150
# 799/799 [==============================] - 0s 250us/step - loss: 0.5281 - acc: 0.6608
# Epoch 81/150
# 799/799 [==============================] - 0s 188us/step - loss: 0.5288 - acc: 0.6633
# Epoch 82/150
# 799/799 [==============================] - 0s 194us/step - loss: 0.5272 - acc: 0.6771
# Epoch 83/150
# 799/799 [==============================] - 0s 276us/step - loss: 0.5285 - acc: 0.6571
# Epoch 84/150
# 799/799 [==============================] - 0s 181us/step - loss: 0.5319 - acc: 0.6421
# Epoch 85/150
# 799/799 [==============================] - 0s 204us/step - loss: 0.5279 - acc: 0.6521
# Epoch 86/150
# 799/799 [==============================] - 0s 230us/step - loss: 0.5299 - acc: 0.6496
# Epoch 87/150
# 799/799 [==============================] - 0s 201us/step - loss: 0.5306 - acc: 0.6633
# Epoch 88/150
# 799/799 [==============================] - 0s 177us/step - loss: 0.5327 - acc: 0.6546
# Epoch 89/150
# 799/799 [==============================] - 0s 179us/step - loss: 0.5373 - acc: 0.6758
# Epoch 90/150
# 799/799 [==============================] - 0s 174us/step - loss: 0.5316 - acc: 0.6621
# Epoch 91/150
# 799/799 [==============================] - 0s 212us/step - loss: 0.5315 - acc: 0.6345
# Epoch 92/150
# 799/799 [==============================] - 0s 187us/step - loss: 0.5317 - acc: 0.6458
# Epoch 93/150
# 799/799 [==============================] - 0s 186us/step - loss: 0.5341 - acc: 0.6558
# Epoch 94/150
# 799/799 [==============================] - 0s 187us/step - loss: 0.5270 - acc: 0.6608
# Epoch 95/150
# 799/799 [==============================] - 0s 188us/step - loss: 0.5340 - acc: 0.6421
# Epoch 96/150
# 799/799 [==============================] - 0s 206us/step - loss: 0.5296 - acc: 0.6558
# Epoch 97/150
# 799/799 [==============================] - 0s 210us/step - loss: 0.5277 - acc: 0.6621
# Epoch 98/150
# 799/799 [==============================] - 0s 230us/step - loss: 0.5402 - acc: 0.6421
# Epoch 99/150
# 799/799 [==============================] - 0s 277us/step - loss: 0.5320 - acc: 0.6258
# Epoch 100/150
# 799/799 [==============================] - 0s 219us/step - loss: 0.5312 - acc: 0.6333
# Epoch 101/150
# 799/799 [==============================] - 0s 201us/step - loss: 0.5283 - acc: 0.6496
# Epoch 102/150
# 799/799 [==============================] - 0s 202us/step - loss: 0.5268 - acc: 0.6696
# Epoch 103/150
# 799/799 [==============================] - 0s 208us/step - loss: 0.5268 - acc: 0.6571
# Epoch 104/150
# 799/799 [==============================] - 0s 207us/step - loss: 0.5285 - acc: 0.6596
# Epoch 105/150
# 799/799 [==============================] - 0s 207us/step - loss: 0.5286 - acc: 0.6370
# Epoch 106/150
# 799/799 [==============================] - 0s 210us/step - loss: 0.5282 - acc: 0.6446
# Epoch 107/150
# 799/799 [==============================] - 0s 204us/step - loss: 0.5272 - acc: 0.6721
# Epoch 108/150
# 799/799 [==============================] - 0s 200us/step - loss: 0.5273 - acc: 0.6671
# Epoch 109/150
# 799/799 [==============================] - 0s 204us/step - loss: 0.5283 - acc: 0.6458
# Epoch 110/150
# 799/799 [==============================] - 0s 212us/step - loss: 0.5269 - acc: 0.6583
# Epoch 111/150
# 799/799 [==============================] - 0s 206us/step - loss: 0.5263 - acc: 0.6521
# Epoch 112/150
# 799/799 [==============================] - 0s 194us/step - loss: 0.5304 - acc: 0.6558
# Epoch 113/150
# 799/799 [==============================] - 0s 193us/step - loss: 0.5270 - acc: 0.6508
# Epoch 114/150
# 799/799 [==============================] - 0s 204us/step - loss: 0.5266 - acc: 0.6621
# Epoch 115/150
# 799/799 [==============================] - 0s 207us/step - loss: 0.5297 - acc: 0.6433
# Epoch 116/150
# 799/799 [==============================] - 0s 203us/step - loss: 0.5269 - acc: 0.6421
# Epoch 117/150
# 799/799 [==============================] - 0s 201us/step - loss: 0.5272 - acc: 0.6421
# Epoch 118/150
# 799/799 [==============================] - 0s 191us/step - loss: 0.5444 - acc: 0.6458
# Epoch 119/150
# 799/799 [==============================] - 0s 189us/step - loss: 0.5239 - acc: 0.6696
# Epoch 120/150
# 799/799 [==============================] - 0s 194us/step - loss: 0.5258 - acc: 0.6458
# Epoch 121/150
# 799/799 [==============================] - 0s 205us/step - loss: 0.5308 - acc: 0.6596
# Epoch 122/150
# 799/799 [==============================] - 0s 204us/step - loss: 0.5320 - acc: 0.6621
# Epoch 123/150
# 799/799 [==============================] - 0s 294us/step - loss: 0.5345 - acc: 0.6733
# Epoch 124/150
# 799/799 [==============================] - 0s 239us/step - loss: 0.5299 - acc: 0.6596
# Epoch 125/150
# 799/799 [==============================] - 0s 228us/step - loss: 0.5329 - acc: 0.6783
# Epoch 126/150
# 799/799 [==============================] - 0s 229us/step - loss: 0.5277 - acc: 0.6646
# Epoch 127/150
# 799/799 [==============================] - 0s 223us/step - loss: 0.5319 - acc: 0.6646
# Epoch 128/150
# 799/799 [==============================] - 0s 218us/step - loss: 0.5268 - acc: 0.6571
# Epoch 129/150
# 799/799 [==============================] - 0s 219us/step - loss: 0.5255 - acc: 0.6733
# Epoch 130/150
# 799/799 [==============================] - 0s 218us/step - loss: 0.5268 - acc: 0.6658
# Epoch 131/150
# 799/799 [==============================] - 0s 253us/step - loss: 0.5262 - acc: 0.6370
# Epoch 132/150
# 799/799 [==============================] - 0s 230us/step - loss: 0.5294 - acc: 0.6533
# Epoch 133/150
# 799/799 [==============================] - 0s 227us/step - loss: 0.5328 - acc: 0.6521
# Epoch 134/150
# 799/799 [==============================] - 0s 275us/step - loss: 0.5314 - acc: 0.6546
# Epoch 135/150
# 799/799 [==============================] - 0s 218us/step - loss: 0.5289 - acc: 0.6521
# Epoch 136/150
# 799/799 [==============================] - 0s 221us/step - loss: 0.5235 - acc: 0.6621
# Epoch 137/150
# 799/799 [==============================] - 0s 271us/step - loss: 0.5326 - acc: 0.6671
# Epoch 138/150
# 799/799 [==============================] - 0s 322us/step - loss: 0.5289 - acc: 0.6834
# Epoch 139/150
# 799/799 [==============================] - 0s 251us/step - loss: 0.5284 - acc: 0.6608
# Epoch 140/150
# 799/799 [==============================] - 0s 275us/step - loss: 0.5267 - acc: 0.6596
# Epoch 141/150
# 799/799 [==============================] - 0s 301us/step - loss: 0.5280 - acc: 0.6621
# Epoch 142/150
# 799/799 [==============================] - 0s 223us/step - loss: 0.5276 - acc: 0.6683
# Epoch 143/150
# 799/799 [==============================] - 0s 217us/step - loss: 0.5249 - acc: 0.6533
# Epoch 144/150
# 799/799 [==============================] - 0s 200us/step - loss: 0.5239 - acc: 0.6721
# Epoch 145/150
# 799/799 [==============================] - 0s 194us/step - loss: 0.5257 - acc: 0.6558
# Epoch 146/150
# 799/799 [==============================] - 0s 207us/step - loss: 0.5306 - acc: 0.6621
# Epoch 147/150
# 799/799 [==============================] - 0s 234us/step - loss: 0.5269 - acc: 0.6721
# Epoch 148/150
# 799/799 [==============================] - 0s 277us/step - loss: 0.5252 - acc: 0.6521
# Epoch 149/150
# 799/799 [==============================] - 0s 247us/step - loss: 0.5310 - acc: 0.6558
# Epoch 150/150
# 799/799 [==============================] - 0s 288us/step - loss: 0.5227 - acc: 0.6658

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))

# clearing the memory
del model
del accuracy
# Out:
# 200/200 [==============================] - 0s 427us/step
# Accuracy: 60.50
