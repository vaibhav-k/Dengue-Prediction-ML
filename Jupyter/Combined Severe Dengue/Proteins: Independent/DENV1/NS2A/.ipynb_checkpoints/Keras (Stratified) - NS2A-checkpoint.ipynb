# %%
# Importing the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Importing the protein data
k2 = []
k2d = []

f = open("../../../../../../Data/Proteins/DENV1/NS2A/DENV1_NS2A.txt", "r")
for x in f:
    if "DSS" in x:
        k2d.append(1)
    elif "DHF" in x:
        k2d.append(1)
    elif x[0] == ">":
        k2d.append(0)
    else:
        x = x.replace("\n", "")
        k2.append(x)
        
# Converting the array into DataFrame
k2 = pd.DataFrame(k2)

# Attaching the "Disease" label column to the input
k2["Disease"] = k2d

# Renaming the columns
k2 = k2.rename(index=str, columns={0: "Sequence", "Disease": "Disease"})

# clearing the memory
del k2d

# %%
print("The combined shape of the given data is:", str(k2.shape))
print("The length of the combined data is:", str(len(k2.index)))
print("Does the combined data have any null value? ->", k2.isnull().values.any())

k2 = k2.dropna(how = 'any', axis = 0) 

# Shuffling the data and then taking a peek
k2 = k2.sample(frac = 1)
# Out:
# The combined shape of the given data is: (999, 2)
# The length of the combined data is: 999
# Does the combined data have any null value? -> False

# %%
# Function to convert sequence strings into k-mer words, default size = 6 (hexamer words)
def getKmers(sequence, size = 6):
    return [sequence[x:x + size].lower() for x in range(len(sequence) - size + 1)]

k2['words'] = k2.apply(lambda x: getKmers(x['Sequence']), axis = 1)
k2 = k2.drop('Sequence', axis=1)

k2_texts = list(k2['words'])
for item in range(len(k2_texts)):
    k2_texts[item] = ' '.join(k2_texts[item])

# %%
# Creating y and printing the shape of it
y = k2.iloc[:, 0].values

# Checking the balance of the disease severity
k2["Disease"].value_counts().sort_index().plot.bar()

# clearing the memory
del k2

# %%
# Creating the Bag of Words model using CountVectorizer()
# This is equivalent to k-mer counting
# The n-gram size of 4 was previously determined by testing
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(ngram_range=(4,4))
x = cv.fit_transform(k2_texts)

# clearing the memory
del cv

# %%
# Splitting the human dataset into the training set and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 42, stratify=y)

# Printing the shapes of the train and test matrices
print("The shape of x_train is:", X_train.shape)
print("The shape of y_train is:", y_train.shape)
print("The shape of x_test is:", X_test.shape)
print("The shape of y_test is:", y_test.shape)

# clearing the memory
del x
del y
# Out:
# The shape of x_train is: (799, 1585)
# The shape of y_train is: (799,)
# The shape of x_test is: (200, 1585)
# The shape of y_test is: (200,)

# %% [markdown]
# ## Keras

# %%
# Importing the Keras libraries
from keras.models import Sequential
from keras.layers import Dense

# define the keras model
model = Sequential()
model.add(Dense(12, input_dim=1585, activation='relu'))
model.add(Dense(15, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0323 18:16:25.358529 139638501496640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0323 18:16:25.377371 139638501496640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0323 18:16:25.381046 139638501496640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# fit the keras model on the dataset
model.fit(X_train, y_train, epochs=150, batch_size=10)
# Out:
# W0323 18:16:25.437028 139638501496640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0323 18:16:25.472261 139638501496640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0323 18:16:25.477488 139638501496640 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0323 18:16:25.671541 139638501496640 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/150
# 799/799 [==============================] - 0s 597us/step - loss: 0.6295 - acc: 0.5782
# Epoch 2/150
# 799/799 [==============================] - 0s 178us/step - loss: 0.6081 - acc: 0.6108
# Epoch 3/150
# 799/799 [==============================] - 0s 369us/step - loss: 0.6103 - acc: 0.6208
# Epoch 4/150
# 799/799 [==============================] - 0s 405us/step - loss: 0.6077 - acc: 0.5920
# Epoch 5/150
# 799/799 [==============================] - 0s 402us/step - loss: 0.5980 - acc: 0.5920
# Epoch 6/150
# 799/799 [==============================] - 0s 368us/step - loss: 0.5957 - acc: 0.6083
# Epoch 7/150
# 799/799 [==============================] - 0s 387us/step - loss: 0.5951 - acc: 0.6258
# Epoch 8/150
# 799/799 [==============================] - 0s 374us/step - loss: 0.5848 - acc: 0.6158
# Epoch 9/150
# 799/799 [==============================] - 0s 377us/step - loss: 0.5820 - acc: 0.6308
# Epoch 10/150
# 799/799 [==============================] - 0s 361us/step - loss: 0.5898 - acc: 0.6245
# Epoch 11/150
# 799/799 [==============================] - 0s 343us/step - loss: 0.5721 - acc: 0.6583
# Epoch 12/150
# 799/799 [==============================] - 0s 340us/step - loss: 0.5710 - acc: 0.6370
# Epoch 13/150
# 799/799 [==============================] - 0s 375us/step - loss: 0.5807 - acc: 0.6408
# Epoch 14/150
# 799/799 [==============================] - 0s 408us/step - loss: 0.5707 - acc: 0.6546
# Epoch 15/150
# 799/799 [==============================] - 0s 418us/step - loss: 0.5744 - acc: 0.6270
# Epoch 16/150
# 799/799 [==============================] - 0s 342us/step - loss: 0.5641 - acc: 0.6596
# Epoch 17/150
# 799/799 [==============================] - 0s 371us/step - loss: 0.5693 - acc: 0.6383
# Epoch 18/150
# 799/799 [==============================] - 0s 366us/step - loss: 0.5684 - acc: 0.6208
# Epoch 19/150
# 799/799 [==============================] - 0s 363us/step - loss: 0.5615 - acc: 0.6558
# Epoch 20/150
# 799/799 [==============================] - 0s 331us/step - loss: 0.5642 - acc: 0.6558
# Epoch 21/150
# 799/799 [==============================] - 0s 338us/step - loss: 0.5589 - acc: 0.6608
# Epoch 22/150
# 799/799 [==============================] - 0s 339us/step - loss: 0.5587 - acc: 0.6596
# Epoch 23/150
# 799/799 [==============================] - 0s 342us/step - loss: 0.5545 - acc: 0.6533
# Epoch 24/150
# 799/799 [==============================] - 0s 334us/step - loss: 0.5621 - acc: 0.6533
# Epoch 25/150
# 799/799 [==============================] - 0s 315us/step - loss: 0.5581 - acc: 0.6295
# Epoch 26/150
# 799/799 [==============================] - 0s 358us/step - loss: 0.5545 - acc: 0.6546
# Epoch 27/150
# 799/799 [==============================] - 0s 309us/step - loss: 0.5629 - acc: 0.6395
# Epoch 28/150
# 799/799 [==============================] - 0s 342us/step - loss: 0.5524 - acc: 0.6433
# Epoch 29/150
# 799/799 [==============================] - 0s 332us/step - loss: 0.5533 - acc: 0.6433
# Epoch 30/150
# 799/799 [==============================] - 0s 311us/step - loss: 0.5504 - acc: 0.6571
# Epoch 31/150
# 799/799 [==============================] - 0s 334us/step - loss: 0.5511 - acc: 0.6658
# Epoch 32/150
# 799/799 [==============================] - 0s 348us/step - loss: 0.5488 - acc: 0.6533
# Epoch 33/150
# 799/799 [==============================] - 0s 338us/step - loss: 0.5485 - acc: 0.6608
# Epoch 34/150
# 799/799 [==============================] - 0s 332us/step - loss: 0.5524 - acc: 0.6533
# Epoch 35/150
# 799/799 [==============================] - 0s 309us/step - loss: 0.5453 - acc: 0.6621
# Epoch 36/150
# 799/799 [==============================] - 0s 307us/step - loss: 0.5490 - acc: 0.6621
# Epoch 37/150
# 799/799 [==============================] - 0s 330us/step - loss: 0.5429 - acc: 0.6621
# Epoch 38/150
# 799/799 [==============================] - 0s 364us/step - loss: 0.5447 - acc: 0.6583
# Epoch 39/150
# 799/799 [==============================] - 0s 324us/step - loss: 0.5497 - acc: 0.6521
# Epoch 40/150
# 799/799 [==============================] - 0s 306us/step - loss: 0.5451 - acc: 0.6546
# Epoch 41/150
# 799/799 [==============================] - 0s 311us/step - loss: 0.5470 - acc: 0.6583
# Epoch 42/150
# 799/799 [==============================] - 0s 328us/step - loss: 0.5453 - acc: 0.6383
# Epoch 43/150
# 799/799 [==============================] - 0s 343us/step - loss: 0.5396 - acc: 0.6608
# Epoch 44/150
# 799/799 [==============================] - 0s 381us/step - loss: 0.5458 - acc: 0.6483
# Epoch 45/150
# 799/799 [==============================] - 0s 333us/step - loss: 0.5439 - acc: 0.6521
# Epoch 46/150
# 799/799 [==============================] - 0s 318us/step - loss: 0.5372 - acc: 0.6633
# Epoch 47/150
# 799/799 [==============================] - 0s 334us/step - loss: 0.5427 - acc: 0.6596
# Epoch 48/150
# 799/799 [==============================] - 0s 334us/step - loss: 0.5395 - acc: 0.6696
# Epoch 49/150
# 799/799 [==============================] - 0s 336us/step - loss: 0.5459 - acc: 0.6533
# Epoch 50/150
# 799/799 [==============================] - 0s 310us/step - loss: 0.5353 - acc: 0.6733
# Epoch 51/150
# 799/799 [==============================] - 0s 308us/step - loss: 0.5358 - acc: 0.6521
# Epoch 52/150
# 799/799 [==============================] - 0s 307us/step - loss: 0.5398 - acc: 0.6696
# Epoch 53/150
# 799/799 [==============================] - 0s 334us/step - loss: 0.5316 - acc: 0.6683
# Epoch 54/150
# 799/799 [==============================] - 0s 308us/step - loss: 0.5357 - acc: 0.6671
# Epoch 55/150
# 799/799 [==============================] - 0s 302us/step - loss: 0.5388 - acc: 0.6758
# Epoch 56/150
# 799/799 [==============================] - 0s 303us/step - loss: 0.5484 - acc: 0.6483
# Epoch 57/150
# 799/799 [==============================] - 0s 299us/step - loss: 0.5365 - acc: 0.6633
# Epoch 58/150
# 799/799 [==============================] - 0s 314us/step - loss: 0.5357 - acc: 0.6796
# Epoch 59/150
# 799/799 [==============================] - 0s 314us/step - loss: 0.5329 - acc: 0.6671
# Epoch 60/150
# 799/799 [==============================] - 0s 302us/step - loss: 0.5364 - acc: 0.6658
# Epoch 61/150
# 799/799 [==============================] - 0s 310us/step - loss: 0.5454 - acc: 0.6658
# Epoch 62/150
# 799/799 [==============================] - 0s 310us/step - loss: 0.5347 - acc: 0.6646
# Epoch 63/150
# 799/799 [==============================] - 0s 298us/step - loss: 0.5333 - acc: 0.6809
# Epoch 64/150
# 799/799 [==============================] - 0s 309us/step - loss: 0.5364 - acc: 0.6771
# Epoch 65/150
# 799/799 [==============================] - 0s 351us/step - loss: 0.5332 - acc: 0.6583
# Epoch 66/150
# 799/799 [==============================] - 0s 329us/step - loss: 0.5329 - acc: 0.6671
# Epoch 67/150
# 799/799 [==============================] - 0s 307us/step - loss: 0.5295 - acc: 0.6809
# Epoch 68/150
# 799/799 [==============================] - 0s 301us/step - loss: 0.5319 - acc: 0.6758
# Epoch 69/150
# 799/799 [==============================] - 0s 340us/step - loss: 0.5339 - acc: 0.6596
# Epoch 70/150
# 799/799 [==============================] - 0s 312us/step - loss: 0.5334 - acc: 0.6796
# Epoch 71/150
# 799/799 [==============================] - 0s 313us/step - loss: 0.5318 - acc: 0.6671
# Epoch 72/150
# 799/799 [==============================] - 0s 381us/step - loss: 0.5311 - acc: 0.6758
# Epoch 73/150
# 799/799 [==============================] - 0s 357us/step - loss: 0.5284 - acc: 0.6696
# Epoch 74/150
# 799/799 [==============================] - 0s 336us/step - loss: 0.5298 - acc: 0.6758
# Epoch 75/150
# 799/799 [==============================] - 0s 331us/step - loss: 0.5307 - acc: 0.6834
# Epoch 76/150
# 799/799 [==============================] - 0s 336us/step - loss: 0.5293 - acc: 0.6683
# Epoch 77/150
# 799/799 [==============================] - 0s 315us/step - loss: 0.5321 - acc: 0.6758
# Epoch 78/150
# 799/799 [==============================] - 0s 315us/step - loss: 0.5305 - acc: 0.6921
# Epoch 79/150
# 799/799 [==============================] - 0s 309us/step - loss: 0.5406 - acc: 0.6546
# Epoch 80/150
# 799/799 [==============================] - 0s 301us/step - loss: 0.5285 - acc: 0.6671
# Epoch 81/150
# 799/799 [==============================] - 0s 324us/step - loss: 0.5322 - acc: 0.6483
# Epoch 82/150
# 799/799 [==============================] - 0s 295us/step - loss: 0.5284 - acc: 0.6783
# Epoch 83/150
# 799/799 [==============================] - 0s 310us/step - loss: 0.5280 - acc: 0.6683
# Epoch 84/150
# 799/799 [==============================] - 0s 364us/step - loss: 0.5296 - acc: 0.6758
# Epoch 85/150
# 799/799 [==============================] - 0s 326us/step - loss: 0.5263 - acc: 0.6733
# Epoch 86/150
# 799/799 [==============================] - 0s 347us/step - loss: 0.5275 - acc: 0.6721
# Epoch 87/150
# 799/799 [==============================] - 0s 326us/step - loss: 0.5293 - acc: 0.6834
# Epoch 88/150
# 799/799 [==============================] - 0s 339us/step - loss: 0.5267 - acc: 0.6821
# Epoch 89/150
# 799/799 [==============================] - 0s 334us/step - loss: 0.5302 - acc: 0.6733
# Epoch 90/150
# 799/799 [==============================] - 0s 331us/step - loss: 0.5310 - acc: 0.6809
# Epoch 91/150
# 799/799 [==============================] - 0s 325us/step - loss: 0.5298 - acc: 0.6783
# Epoch 92/150
# 799/799 [==============================] - 0s 330us/step - loss: 0.5297 - acc: 0.6783
# Epoch 93/150
# 799/799 [==============================] - 0s 305us/step - loss: 0.5281 - acc: 0.6683
# Epoch 94/150
# 799/799 [==============================] - 0s 320us/step - loss: 0.5300 - acc: 0.6683
# Epoch 95/150
# 799/799 [==============================] - 0s 318us/step - loss: 0.5291 - acc: 0.6658
# Epoch 96/150
# 799/799 [==============================] - 0s 341us/step - loss: 0.5281 - acc: 0.6758
# Epoch 97/150
# 799/799 [==============================] - 0s 314us/step - loss: 0.5274 - acc: 0.6708
# Epoch 98/150
# 799/799 [==============================] - 0s 336us/step - loss: 0.5284 - acc: 0.6746
# Epoch 99/150
# 799/799 [==============================] - 0s 325us/step - loss: 0.5249 - acc: 0.6846
# Epoch 100/150
# 799/799 [==============================] - 0s 300us/step - loss: 0.5278 - acc: 0.6633
# Epoch 101/150
# 799/799 [==============================] - 0s 334us/step - loss: 0.5278 - acc: 0.6809
# Epoch 102/150
# 799/799 [==============================] - 0s 336us/step - loss: 0.5279 - acc: 0.6658
# Epoch 103/150
# 799/799 [==============================] - 0s 349us/step - loss: 0.5234 - acc: 0.6859
# Epoch 104/150
# 799/799 [==============================] - 0s 337us/step - loss: 0.5289 - acc: 0.6671
# Epoch 105/150
# 799/799 [==============================] - 0s 330us/step - loss: 0.5241 - acc: 0.6921
# Epoch 106/150
# 799/799 [==============================] - 0s 312us/step - loss: 0.5296 - acc: 0.6909
# Epoch 107/150
# 799/799 [==============================] - 0s 299us/step - loss: 0.5287 - acc: 0.6771
# Epoch 108/150
# 799/799 [==============================] - 0s 331us/step - loss: 0.5276 - acc: 0.6721
# Epoch 109/150
# 799/799 [==============================] - 0s 317us/step - loss: 0.5237 - acc: 0.6871
# Epoch 110/150
# 799/799 [==============================] - 0s 331us/step - loss: 0.5304 - acc: 0.6596
# Epoch 111/150
# 799/799 [==============================] - 0s 338us/step - loss: 0.5312 - acc: 0.6821
# Epoch 112/150
# 799/799 [==============================] - 0s 335us/step - loss: 0.5312 - acc: 0.6608
# Epoch 113/150
# 799/799 [==============================] - 0s 320us/step - loss: 0.5277 - acc: 0.6696
# Epoch 114/150
# 799/799 [==============================] - 0s 342us/step - loss: 0.5284 - acc: 0.6859
# Epoch 115/150
# 799/799 [==============================] - 0s 318us/step - loss: 0.5267 - acc: 0.6733
# Epoch 116/150
# 799/799 [==============================] - 0s 328us/step - loss: 0.5269 - acc: 0.6608
# Epoch 117/150
# 799/799 [==============================] - 0s 304us/step - loss: 0.5280 - acc: 0.6671
# Epoch 118/150
# 799/799 [==============================] - 0s 338us/step - loss: 0.5255 - acc: 0.6909
# Epoch 119/150
# 799/799 [==============================] - 0s 332us/step - loss: 0.5252 - acc: 0.6733
# Epoch 120/150
# 799/799 [==============================] - 0s 314us/step - loss: 0.5234 - acc: 0.6533
# Epoch 121/150
# 799/799 [==============================] - 0s 335us/step - loss: 0.5273 - acc: 0.6783
# Epoch 122/150
# 799/799 [==============================] - 0s 334us/step - loss: 0.5290 - acc: 0.6733
# Epoch 123/150
# 799/799 [==============================] - 0s 304us/step - loss: 0.5241 - acc: 0.6821
# Epoch 124/150
# 799/799 [==============================] - 0s 352us/step - loss: 0.5267 - acc: 0.6771
# Epoch 125/150
# 799/799 [==============================] - 0s 336us/step - loss: 0.5286 - acc: 0.6758
# Epoch 126/150
# 799/799 [==============================] - 0s 335us/step - loss: 0.5268 - acc: 0.6846
# Epoch 127/150
# 799/799 [==============================] - 0s 325us/step - loss: 0.5313 - acc: 0.6683
# Epoch 128/150
# 799/799 [==============================] - 0s 337us/step - loss: 0.5228 - acc: 0.6658
# Epoch 129/150
# 799/799 [==============================] - 0s 325us/step - loss: 0.5299 - acc: 0.6884
# Epoch 130/150
# 799/799 [==============================] - 0s 329us/step - loss: 0.5256 - acc: 0.6771
# Epoch 131/150
# 799/799 [==============================] - 0s 358us/step - loss: 0.5228 - acc: 0.6796
# Epoch 132/150
# 799/799 [==============================] - 0s 324us/step - loss: 0.5243 - acc: 0.6796
# Epoch 133/150
# 799/799 [==============================] - 0s 322us/step - loss: 0.5222 - acc: 0.6859
# Epoch 134/150
# 799/799 [==============================] - 0s 349us/step - loss: 0.5243 - acc: 0.6783
# Epoch 135/150
# 799/799 [==============================] - 0s 314us/step - loss: 0.5231 - acc: 0.6896
# Epoch 136/150
# 799/799 [==============================] - 0s 310us/step - loss: 0.5243 - acc: 0.6821
# Epoch 137/150
# 799/799 [==============================] - 0s 312us/step - loss: 0.5236 - acc: 0.6783
# Epoch 138/150
# 799/799 [==============================] - 0s 322us/step - loss: 0.5211 - acc: 0.6946
# Epoch 139/150
# 799/799 [==============================] - 0s 334us/step - loss: 0.5265 - acc: 0.6633
# Epoch 140/150
# 799/799 [==============================] - 0s 320us/step - loss: 0.5223 - acc: 0.6796
# Epoch 141/150
# 799/799 [==============================] - 0s 317us/step - loss: 0.5228 - acc: 0.6746
# Epoch 142/150
# 799/799 [==============================] - 0s 305us/step - loss: 0.5221 - acc: 0.6934
# Epoch 143/150
# 799/799 [==============================] - 0s 335us/step - loss: 0.5224 - acc: 0.6721
# Epoch 144/150
# 799/799 [==============================] - 0s 338us/step - loss: 0.5240 - acc: 0.6708
# Epoch 145/150
# 799/799 [==============================] - 0s 320us/step - loss: 0.5241 - acc: 0.6821
# Epoch 146/150
# 799/799 [==============================] - 0s 304us/step - loss: 0.5241 - acc: 0.6809
# Epoch 147/150
# 799/799 [==============================] - 0s 325us/step - loss: 0.5256 - acc: 0.6783
# Epoch 148/150
# 799/799 [==============================] - 0s 335us/step - loss: 0.5231 - acc: 0.6758
# Epoch 149/150
# 799/799 [==============================] - 0s 355us/step - loss: 0.5255 - acc: 0.6884
# Epoch 150/150
# 799/799 [==============================] - 0s 304us/step - loss: 0.5228 - acc: 0.6683

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))

# clearing the memory
del accuracy
del model
# Out:
# 200/200 [==============================] - 0s 401us/step
# Accuracy: 58.50
